# %%
import os
import time
import pickle

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
from retrying import retry
from urllib.parse import urlparse, parse_qs

# %%
import unidecode
import re
from urllib.parse import urljoin
from dataclasses import dataclass, field, asdict
from datetime import date
from typing import List, Optional
import json

# %%
from utils.scrap_data import SEASON_DATA, CLUB_DATA

# %%
from datetime import datetime

PL_MONTHS = {
    "stycznia": 1,
    "lutego": 2,
    "marca": 3,
    "kwietnia": 4,
    "maja": 5,
    "czerwca": 6,
    "lipca": 7,
    "sierpnia": 8,
    "września": 9,
    "października": 10,
    "listopada": 11,
    "grudnia": 12,
}

# %%
@dataclass
class Transfer:
    season: str
    date: str
    left: str
    joined: str
    mv: str
    fee: str

# %%
@dataclass
class TransfermarktPlayer:
    player_id: int
    name: str
    profile_url: str
    
    date_of_birth: Optional[date] = None
    position: Optional[str] = None
    transfers: Optional[List[Transfer]] = field(default_factory=list)
    id_90minut: Optional[int] = None

# %%
tstest = TransfermarktScrapper()

# %%
buksa = tstest.extract_player_ids_from_search('Adam Buksa')

# %%
buksa[0].player_id
# Out:
# 267160

# %%
tstest.enrich_with_transfers(buksa[0])

# %%
buksa
# Out:
# [TransfermarktPlayer(player_id=267160, name='Adam Buksa', profile_url='https://www.transfermarkt.de/adam-buksa/profil/spieler/267160', date_of_birth=None, position=None, transfers=[Transfer(season='25/26', date='26.08.2025', left='FC Midtjylland', joined='Udinese', mv='6,00 Mio. €', fee='5,00 Mio. €'), Transfer(season='24/25', date='11.07.2024', left='RC Lens', joined='FC Midtjylland', mv='6,00 Mio. €', fee='4,00 Mio. €'), Transfer(season='23/24', date='30.06.2024', left='Antalyaspor', joined='RC Lens', mv='6,00 Mio. €', fee='Leih-Ende'), Transfer(season='23/24', date='18.07.2023', left='RC Lens', joined='Antalyaspor', mv='5,00 Mio. €', fee='Leihe'), Transfer(season='22/23', date='01.07.2022', left='New England', joined='RC Lens', mv='9,00 Mio. €', fee='6,00 Mio. €'), Transfer(season='19/20', date='01.01.2020', left='Pogon Stettin', joined='New England', mv='1,00 Mio. €', fee='4,20 Mio. €'), Transfer(season='18/19', date='01.07.2018', left='Zaglebie Lubin', joined='Pogon Stettin', mv='200 Tsd. €', fee='350 Tsd. €'), Transfer(season='17/18', date='30.06.2018', left='Pogon Stettin', joined='Zaglebie Lubin', mv='200 Tsd. €', fee='Leih-Ende'), Transfer(season='17/18', date='08.01.2018', left='Zaglebie Lubin', joined='Pogon Stettin', mv='225 Tsd. €', fee='Leihgebühr:<br /><i class="normaler-text">25 Tsd. €</i>'), Transfer(season='16/17', date='31.08.2016', left='Lechia Gdansk', joined='Zaglebie Lubin', mv='150 Tsd. €', fee='50 Tsd. €'), Transfer(season='14/15', date='01.07.2014', left='Novara U19', joined='Lechia Gdansk', mv='75 Tsd. €', fee='ablösefrei'), Transfer(season='13/14', date='01.07.2013', left='Wisla U19', joined='Novara U19', mv='-', fee='5 Tsd. €'), Transfer(season='12/13', date='01.01.2013', left='Garbarnia U19', joined='Wisla U19', mv='-', fee='ablösefrei')], id_90minut=None)]

# %%
class TransfermarktScrapper():
    BASE_URL = 'https://www.transfermarkt.de'
    QUERY_URL = BASE_URL+'/schnellsuche/ergebnis/schnellsuche?query='
    TRANSFER_URL = BASE_URL+r'/ceapi/transferHistory/list/'
    HEADERS = {"User-Agent": "Mozilla/5.0"}
    def __init__(self):
        pass

    @staticmethod
    def _normalize_name(name: str) -> str:
        ''' 
        Normalize name for a search request
        '''
        name = unidecode.unidecode(name.lower())
        name = re.sub(r'[^a-z\s-]', '', name)
        #name = re.sub(r'[-]', ' ', name)
        name = re.sub(r'\s+', ' ', name)
        return name.replace(' ', '+').strip()
        
    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def extract_player_ids_from_search(self, name_raw: str) -> list[TransfermarktPlayer]:
        name_formatted = self._normalize_name(name_raw)
        resp = requests.get(self.QUERY_URL+name_formatted, headers=self.HEADERS)
        soup = BeautifulSoup(resp.text, "lxml")
    
        table = soup.find("table", class_="items")
        players = []
        
        if not table:
            return []
    
        for row in table.tbody.find_all("tr", recursive=False):
            name_cell = row.find("td", class_="hauptlink")
            if not name_cell:
                continue
    
            a = name_cell.find("a", href=True)
            if not a:
                continue
    
            href = a["href"]
            player_id = href.rstrip("/").split("/")[-1]
    
            players.append(TransfermarktPlayer(
                player_id = int(player_id),
                name = a.get_text(strip=True),
                profile_url = urljoin(self.BASE_URL, href),
            ))
    
        return players

    @staticmethod
    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def enrich_with_dob_and_position(player: TransfermarktPlayer) -> None:
        resp = requests.get(player.profile_url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(resp.text, "html.parser")
        meta = soup.find("meta", attrs={"name": "description"})
        
        if not meta:
            pass
        else:
            dates = re.findall(r"(\d{2}\.\d{2}\.\d{4})", meta['content'])
            if len(dates) > 0:
                player.date_of_birth = min(dates, key=lambda d: datetime.strptime(d, '%d.%m.%Y'))
            
            parts = [p.strip() for p in meta['content'].split("➤")]
            if len(parts) >= 3:
                player.position = parts[2]

    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def enrich_with_transfers(self, player: TransfermarktPlayer) -> None:
        resp = requests.get(self.TRANSFER_URL+str(player.player_id), headers=self.HEADERS).text
        resp_json = json.loads(resp)
        for val in resp_json["transfers"]:
            player.transfers.append(
                Transfer(
                season = val["season"],
                date = val["date"],
                fee = val["fee"],
                mv = val["marketValue"],
                joined =  val["to"]["clubName"],
                left =  val["from"]["clubName"]
                ))

# %%
class Scrapper():
    def __init__(self):
        pass

    @staticmethod
    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def extract_table(link: str = None, league_id: int = None, url_var: int = None) -> pd.DataFrame:
        '''Template URL: http://www.90minut.pl/liga/YYY/ligaXXX.html
        XXX refers to league ID
        YYY refers to the variable in URL (until season 2018/2019 -> 0, after that season -> 1)
        Example URL: Template URL: http://www.90minut.pl/liga/0/liga6826.html'''
        
        time.sleep(3)
        if link is not None:
            resp = requests.get(link, headers={"User-Agent": "Mozilla/5.0"})
        else:
            url = f'http://www.90minut.pl/liga/{url_var}/liga{league_id}.html'
            resp = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(resp.text, "html.parser")
        tables = soup.find_all('table')
        table = pd.read_html(StringIO(str(tables[3])), header = 3, index_col = 0)[0].iloc[:,:7].dropna(how = 'all')
        table = table[table['Nazwa'].isin(CLUB_DATA.keys()) == True] #keeping only records containing club names in the club name column
        table = table.astype({'M.': 'int32', 'Z.': 'int32', 'R.': 'int32', 'P.': 'int32'})
        table['Pkt.'] = table['Pkt.'].apply(lambda x : str(x))
        return table

    @staticmethod
    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def extract_team_season_stats(link: str = None, club_id: int = None, season_id: int = None, league_id: int = None) -> list[pd.DataFrame, list]:
        '''Template URL: http://www.90minut.pl/bilans.php?id_klub=XXX&id_sezon=YY&id=ZZZ
        XXX refers to league ID
        YY refers to season ID
        ZZ refers to league ID
        Example URL: http://www.90minut.pl/bilans.php?id_klub=171&id_sezon=83&id=6826
        
        Returns 2-element list:
        1st element: all players stats
        2nd element: dict of players names and links to profile'''

        time.sleep(3)
        if link is not None:
            resp = requests.get(link, headers={"User-Agent": "Mozilla/5.0"})
        else:
            url = f'http://www.90minut.pl/bilans.php?id_klub={club_id}&id_sezon={season_id}&id={league_id}'
            resp = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(resp.text, "html.parser")
        tables = soup.find_all('table')
        table_main = pd.read_html(StringIO(str(tables[3])), header = 2, index_col = 0)[0].iloc[:-1,:4].dropna(how = 'all')
        table_main = table_main.astype({'w.': 'int32', 'pełne' : 'int32', 'z ławki': 'int32', 'czas': 'int32'})
        links_list = pd.read_html(StringIO(str(tables[3])), header = 2, extract_links = 'all')[0].iloc[:-2,0].dropna(how = 'all').to_list()
        links_dict = {el[0] : el[1] for el in links_list}
        return [table_main, links_dict]

    @staticmethod
    @retry(stop_max_attempt_number=5, wait_random_min=10000, wait_random_max=20000) #5 retries, wait between 10-20 seconds between each retry
    def extract_player_information(link: str = None, player_id: int = None, season_id: int = None) -> dict:
        '''Template URL: http://www.90minut.pl/wystepy.php?id=XXX&id_sezon=ZZ
        XXX refers to player ID
        ZZZ refers to season ID
        Example URL: http://www.90minut.pl/wystepy.php?id=8311&id_sezon=83'''

        time.sleep(3)
        if link is not None:
            resp = requests.get(link, headers={"User-Agent": "Mozilla/5.0"})
        else:
            url = f'http://www.90minut.pl/wystepy.php?id={player_id}&id_sezon={season_id}'
            resp = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(resp.text, "html.parser")
        tables = soup.find_all('table')
        res = pd.read_html(StringIO(str(tables[0])), header = 0, index_col = 1)[0].iloc[:,1:].transpose().dropna(how = 'all')
        res_dict = {'country' : res.loc[:, 'Kraj'].iat[0],
                    'date_of_birth' : ' '.join(res.loc[:, 'Data urodzenia'].iat[0].split()[:3]),
                    'year_of_birth' : res.loc[:, 'Data urodzenia'].iat[0].split()[2]}
        return res_dict

# %%
class DataManipulator():
    def __init__(self):
        self.season_data_path = '../data/season_data.parquet'
        self.player_season_data_path = '../data/player_season_data.parquet'
        self.player_personal_data_path = '../data/player_personal_data.pickle'
        self.player_final_data_path = '../data/player_final_data.parquet'
        self.player_final_data_season_level_path = '../data/player_final_data_season_level.parquet'
        self.transfermarkt_player_data = '../data/transfermarkt_player_data.json'
        self.transfermarkt_player_data_no_match = '../data/transfermarkt_player_data_no_match.json'
        self.scrapper = Scrapper()
        self.t_scrapper = TransfermarktScrapper()

    @staticmethod
    def _save_pickle(file_object, path):
        with open(path, 'wb') as file:
            pickle.dump(file_object, file)
    
    @staticmethod
    def _load_pickle(path):
        with open(path, 'rb') as file:
            a = pickle.load(file)
            return a

    def _save_json(self, data, path):
        with open(path, "w", encoding="utf-8") as f:
            json.dump([asdict(p) for p in data], f, ensure_ascii=False, indent=2)
        print(f'File saved succesfully. Path: {path}')

    @staticmethod
    def _parse_player(data):
        data["transfers"] = [Transfer(**t) for t in data["transfers"]]
        return TransfermarktPlayer(**data)
    
    def _load_json(self, path):
        with open(path, "r", encoding="utf-8") as f:
            data = [self._parse_player(p) for p in json.load(f)]
        return data
        
    @staticmethod
    def _get_player_id(link: str) -> int:
        '''Extracts player ID from the player link
        Example: http://www.90minut.pl/wystepy.php?id=44893&id_sezon=103
        Player ID: 44893
        '''
        query = parse_qs(urlparse(link).query)
        return int(query['id'][0])
        
    def generate_season_data(self, overwrite = False) -> pd.DataFrame:
        '''Generates season_data.parquet file if it does not exist.
        If it exists, it checks whether all seasons are there.
        If yes, it doesn't do anything.'''

        if os.path.isfile(self.season_data_path) == False or \
        (os.path.isfile(self.season_data_path) == True and overwrite == True):
            final_df = pd.DataFrame()
            for k, v in SEASON_DATA.items():
                print(f'Extracting season: {k} data')
                tmp_df = self.scrapper.extract_table(league_id = v['LeagueID'], url_var = v['UrlVar'])
                tmp_df['Sezon'] = k
                final_df = pd.concat([final_df, tmp_df])
            print('Extraction completed.')
            final_df = final_df.astype({'Sezon': 'category'})
            final_df.index = final_df.index.map(str)
            final_df.to_parquet(self.season_data_path, engine = 'fastparquet')
            print(f'Data saved in the following path: {self.season_data_path}')

    def season_data_completness_check(self):
        if os.path.isfile(self.season_data_path) == True:
            print(f'File {self.season_data_path} already exists. Checking data completness')
            data_df = pd.read_parquet(self.season_data_path, engine = 'fastparquet')
            for season, value in SEASON_DATA.items():
                print(f'''Season: {season}, expected number of teams: {value['TeamsNumber']}, actual number of teams: {data_df[data_df['Sezon'] == season].shape[0]}''')
                if data_df[data_df['Sezon'] == season].shape[0] == value['TeamsNumber']:
                    print(f'Season: {season}, all ok.')
                else:
                    print(f'Season: {season} something is wrong, fix the data.')
        else:
            print('Season data file does not exist.')

    def generate_player_data(self) -> pd.DataFrame:
        '''Generates player_data.parquet file
        Requires season_data.parquet prior to be generated. If there is no it generates one.'''

        print('Checking for season_data.parquet')
        if os.path.isfile(self.season_data_path):
            print('File exists. Loading it.')
            clubs_data =  pd.read_parquet(self.season_data_path, engine = 'fastparquet')
        else:
            print('File does not exists. Generating one.')
            self.generate_season_data()
            clubs_data =  pd.read_parquet(self.season_data_path, engine = 'fastparquet')
        
        #loading season player data df
        if os.path.isfile(self.player_season_data_path):
            player_season_df = pd.read_parquet(self.player_season_data_path, engine = 'fastparquet')
        else:
            player_season_df = pd.DataFrame(columns=['w.', 'pełne', 'z ławki', 'czas', 'Sezon', 'Klub', 'ID'])
            player_season_df = player_season_df.astype({'w.': 'int32', 'pełne' : 'int32', 'z ławki': 'int32', 'czas': 'int32', 'ID': 'int32'})
            player_season_df = player_season_df.astype({'Sezon': 'category', 'Klub': 'category'})
        
        #loading personal player data dict
        if os.path.isfile(self.player_personal_data_path):
            player_personal_dict = self._load_pickle(self.player_personal_data_path)
        else:
            player_personal_dict = {}
            
        #iterating thhrough seasons
        for k,v in SEASON_DATA.items():
            print(f'*** Scrapping season: {k}')
            season_clubs = clubs_data[clubs_data['Sezon'].isin([k]) == True]['Nazwa'].to_list()
            #iterating through clubs
            for club in season_clubs:
                if len(player_season_df[(player_season_df['Sezon'] == k) & (player_season_df['Klub'] == club)].index) > 0:
                    print(f'Club: {club} in season: {k} has been already scrapped')
                    continue
                else:
                    print(f'** Scrapping club: {club} in season: {k}')
                    team_df, player_links = self.scrapper.extract_team_season_stats(club_id = CLUB_DATA[club], season_id = v['SeasonID'], league_id = v['LeagueID'])
                    team_df['Sezon'] = k
                    team_df['Klub'] = club
                    team_df = team_df.astype({'Sezon': 'category', 'Klub': 'category'})
                    #iterating through players
                    for player in team_df.index:
                        player_id = self._get_player_id(player_links[player])
                        team_df.at[player, 'ID'] = player_id
                        if player_id in player_personal_dict.keys():
                            print(f'Player: {player}, ID: {player_id} has been already scrapped')
                            continue
                        else:
                            print(f'* Scrapping player: {player}, ID: {player_id}')
                            player_dict = self.scrapper.extract_player_information(link = 'http://www.90minut.pl'+player_links[player])
                            player_dict['Imie i nazwisko'] = player
                            player_personal_dict[player_id] = player_dict
                        
                        print('Saving players personal data')
                        self._save_pickle(player_personal_dict, self.player_personal_data_path)
                    
                    player_season_df = pd.concat([player_season_df, team_df])
                    print('Saving players season data')
                    player_season_df.to_parquet(self.player_season_data_path, engine = 'fastparquet')
                
        print('Scrapping completed')
        print(f'Player season data saved in the following path: {self.player_season_data_path}')
        player_season_df.to_parquet(self.player_season_data_path, engine = 'fastparquet')
        print(f'Player personal data saved in the following path: {self.player_personal_data_path}')
        self._save_pickle(player_personal_dict, self.player_personal_data_path)
        
    def merge_season_player_data(self, season_agg = False):
        '''Generating dataframe containing combined season and personal players data.
        Requires both player_season_data.parquet and player_personal_data.pickle files.
        
        season_agg: if True, ignores club information and aggregates information at a season level.
        For example, if one player played in two clubs during one season, metrics from both
        clubs will be aggregated at a season level.'''

        season = pd.read_parquet(self.player_season_data_path, engine = 'fastparquet')
        if season_agg:
            season = season.reset_index(drop = False, names = 'Imie i Nazwisko')
            season = season[['Sezon', 'ID', 'Imie i Nazwisko', 'w.', 'pełne', 'z ławki', 'czas']].groupby(['Sezon', 'ID', 'Imie i Nazwisko']).sum()
            season = season.reset_index()
        else:
            season = season.reset_index(names = 'Imie i Nazwisko')

        personal = self._load_pickle(self.player_personal_data_path)

        season.loc[: ,'Polskie Obywatelstwo'] = False
        season.loc[: ,'Wiek'] = 0
        season.loc[: ,'Status Młodzieżowca'] = False
        season.loc[: ,'Przepis Aktywny'] = 'przed'
        season.loc[:, 'Poniżej 900 minut'] = False
        season.loc[:, 'Powyżej 900 minut'] = False
        season.loc[:, 'Pełne 10 meczów'] = False
        season.loc[:, 'Zmieniony 10 meczów'] = False
        season.loc[:, 'Wszedł z ławki 10 meczow'] = False
        season.loc[:, 'Powyżej 1620 minut'] = False
        season.loc[:, 'Pełne 18 meczów'] = False
        season.loc[:, 'Zmieniony 18 meczów'] = False
        season.loc[:, 'Wszedł z ławki 18 meczow'] = False
        season.loc[:, 'Młodzieżowiec ostatni sezon'] = False
        season.loc[:, 'Senior pierwszy sezon'] = False

        for idx in season.index:
            print(f'Processing row no {str(idx)} out of {len(season.index)}')
            season.at[idx, 'Wiek'] = int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth'])
            
            if 'Polska' in personal[season.at[idx, 'ID']]['country']:
                season.at[idx, 'Polskie Obywatelstwo'] = True
            
            if season.at[idx, 'Sezon'] != '2019/2020' and int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth']) <= 22 and season.at[idx, 'Polskie Obywatelstwo'] == True:
                season.at[idx, 'Status Młodzieżowca'] = True

            if season.at[idx, 'Sezon'] == '2019/2020' and int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth']) <= 23 and season.at[idx, 'Polskie Obywatelstwo'] == True:
                season.at[idx, 'Status Młodzieżowca'] = True

            if season.at[idx, 'Sezon'] in ('2019/2020', '2020/2021', '2021/2022', '2022/2023', '2023/2024', '2024/2025'):
                season.at[idx, 'Przepis Aktywny'] = 'w trakcie'

            if season.at[idx, 'czas'] < 900:
                season.at[idx, 'Poniżej 900 minut'] = True
                
            if season.at[idx, 'czas'] >= 900:
                season.at[idx, 'Powyżej 900 minut'] = True

            if season.at[idx, 'pełne'] >= 10:
                season.at[idx, 'Pełne 10 meczów'] = True

            if season.at[idx, 'w.'] - season.at[idx, 'pełne'] - season.at[idx, 'z ławki'] >= 10:
                season.at[idx, 'Zmieniony 10 meczów'] = True

            if season.at[idx, 'z ławki'] >= 10:
                season.at[idx, 'Wszedł z ławki 10 meczow'] = True
                
            if season.at[idx, 'czas'] >= 1620:
                season.at[idx, 'Powyżej 1620 minut'] = True

            if season.at[idx, 'pełne'] >= 18:
                season.at[idx, 'Pełne 18 meczów'] = True

            if season.at[idx, 'w.'] - season.at[idx, 'pełne'] - season.at[idx, 'z ławki'] >= 18:
                season.at[idx, 'Zmieniony 18 meczów'] = True

            if season.at[idx, 'z ławki'] >= 18:
                season.at[idx, 'Wszedł z ławki 18 meczow'] = True
            
            if season.at[idx, 'Sezon'] != '2018/2019' and int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth']) == 22 and season.at[idx, 'Polskie Obywatelstwo'] == True:
                season.at[idx, 'Młodzieżowiec ostatni sezon'] = True

            if season.at[idx, 'Sezon'] == '2019/2020' and int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth']) == 23 and season.at[idx, 'Polskie Obywatelstwo'] == True:
                season.at[idx, 'Młodzieżowiec ostatni sezon'] = True

            if season.at[idx, 'Sezon'] != '2019/2020' and int(season.at[idx, 'Sezon'].split(r'/')[1]) - int(personal[season.at[idx, 'ID']]['year_of_birth']) == 23 and season.at[idx, 'Polskie Obywatelstwo'] == True:
                season.at[idx, 'Senior pierwszy sezon'] = True

            if not season_agg:    
                if season.at[idx, 'Klub'] == 'Termalica Bruk-Bet Nieciecza':
                    season.at[idx, 'Klub'] = 'Bruk-Bet Termalica Nieciecza'
                
        print('Merging completed')
        if season_agg:
            season.to_parquet(self.player_final_data_season_level_path, engine = 'fastparquet')
            print(f'Final data saved in the following path: {self.player_final_data_season_level_path}')
        else:
            season.to_parquet(self.player_final_data_path, engine = 'fastparquet')
            print(f'Final data saved in the following path: {self.player_final_data_path}')

    @staticmethod
    def _parse_polish_date(text: str) -> str:
        day_str, month_pl, year_str = text.split()
        day = int(day_str)
        month = PL_MONTHS[month_pl.lower()]
        year = int(year_str)
    
        return f"{day:02d}.{month:02d}.{year}"

    def map_transfermarkt_data(self):
        if os.path.exists(self.player_personal_data_path) and os.path.exists(self.player_final_data_season_level_path):
            print('Loading 90minut player data')
            dob_90mins = dm._load_pickle(self.player_personal_data_path)
            all_players = pd.read_parquet(self.player_final_data_season_level_path, engine = 'fastparquet')
            young_players_df = all_players[all_players['Status Młodzieżowca'] == True][['ID', 'Imie i Nazwisko']].drop_duplicates()
        else:
            print('No 90 minutes data.')
            return None

        if os.path.exists(self.transfermarkt_player_data):
            print('Loading transfermarkt scrapped data')
            final_players_list = dm._load_json(self.transfermarkt_player_data)
            scrapped_ids = [e.id_90minut for e in final_players_list]
            no_match_results = []
        else:
            print('No transfermarkt data has been generated yet.')
            final_players_list = []
            scrapped_ids = []
            no_match_results = []

        time.sleep(3)
        for idx in young_players_df.index:
            name = young_players_df.at[idx, 'Imie i Nazwisko']
            id_90minut = young_players_df.at[idx, 'ID']
            dob = self._parse_polish_date(dob_90mins[id_90minut]['date_of_birth'])

            if id_90minut in scrapped_ids:
                print(f'Player: {name} information already scrapped')
                continue
                
            print(f'*** Searching for: {name}')
            search_results = self.t_scrapper.extract_player_ids_from_search(name)

            if len(search_results) == 0:
                print('No results found')
                no_match_results.append(
                TransfermarktPlayer(
                    player_id = None,
                    name = None,
                    profile_url = None,
                    id_90minut = id_90minut
                    )
                )
                self._save_json(no_match_results, self.transfermarkt_player_data_no_match)
                continue
            
            print(f'{len(search_results)} results found')
            print('Adding dob and position')
            for result in search_results:
                time.sleep(1)
                self.t_scrapper.enrich_with_dob_and_position(result)

            print('Matching with 90minut data')
            is_match = False
            for result in search_results:
                if dob == result.date_of_birth:
                    print('Match found. Generating transfer data.')
                    time.sleep(1)
                    self.t_scrapper.enrich_with_transfers(result)
                    result.id_90minut = int(id_90minut)
                    final_players_list.append(result)
                    is_match = True
                    self._save_json(final_players_list, self.transfermarkt_player_data)
            if is_match == False:
                for result in search_results:
                    print(f'No match found for player: {name}')
                    time.sleep(1)
                    self.t_scrapper.enrich_with_transfers(result)
                    result.id_90minut = int(id_90minut)
                    no_match_results.append(result)
                    self._save_json(no_match_results, self.transfermarkt_player_data_no_match)

# %%
dm = DataManipulator()

# %%
dm.generate_season_data(overwrite = True)

# %%
dm.season_data_completness_check()

# %%
dm.generate_player_data()

# %%
dm.merge_season_player_data()

# %%
dm.merge_season_player_data(season_agg = True)

# %%
dm.map_transfermarkt_data()
# Out:
# Loading 90minut player data
# Loading transfermarkt scrapped data
# Player: Piotr Mroziński information already scrapped
# Player: Damian Dąbrowski information already scrapped
# Player: Wojciech Golla information already scrapped
# Player: Michał Chrapek information already scrapped
# Player: Jan Pawłowski information already scrapped
# Player: Rafał Janicki information already scrapped
# Player: Marcin Kamiński information already scrapped
# Player: Michał Czekaj information already scrapped
# Player: Dominik Kun information already scrapped
# Player: Maciej Krakowiak information already scrapped
# Player: Michał Żyro information already scrapped
# Player: Wojciech Lisowski information already scrapped
# Player: Michał Efir information already scrapped
# Player: Jakub Szumski information already scrapped
# Player: Bartosz Bereszyński information already scrapped
# Player: Mateusz Kupczak information already scrapped
# Player: Michał Kopczyński information already scrapped
# Player: Dominik Furman information already scrapped
# Player: Wojciech Pawłowski information already scrapped
# Player: Jakub Bąk information already scrapped
# Player: Tomasz Kowalski information already scrapped
# Player: Adam Radecki information already scrapped
# Player: Szymon Drewniak information already scrapped
# Player: Mateusz Lewandowski information already scrapped
# Player: Mateusz Janiec information already scrapped
# Player: Filip Modelski information already scrapped
# Player: Rafał Augustyniak information already scrapped
# Player: Bartłomiej Pawłowski information already scrapped
# Player: Bartosz Szeliga information already scrapped
# Player: Adam Pazio information already scrapped
# Player: Mateusz Kwiatkowski information already scrapped
# Player: Michał Nalepa information already scrapped
# Player: Tomasz Ptak information already scrapped
# Player: Patryk Fryc information already scrapped
# Player: Kamil Włodyka information already scrapped
# Player: Bartosz Kwiecień information already scrapped
# Player: Kornel Osyra information already scrapped
# Player: Mateusz Cichocki information already scrapped
# Player: Krystian Nowak information already scrapped
# Player: Mariusz Rybicki information already scrapped
# Player: Michał Szewczyk information already scrapped
# Player: Tomasz Kędziora information already scrapped
# Player: Rafał Kurzawa information already scrapped
# Player: Sebastian Bartlewski information already scrapped
# Player: Michał Jakóbowski information already scrapped
# Player: Dawid Kudła information already scrapped
# Player: Łukasz Zejdler information already scrapped
# Player: Radosław Wiśniewski information already scrapped
# Player: Tomasz Porębski information already scrapped
# Player: Karol Mackiewicz information already scrapped
# Player: Alan Uryga information already scrapped
# Player: Łukasz Kacprzycki information already scrapped
# Player: Damian Kugiel information already scrapped
# Player: Seweryn Michalski information already scrapped
# Player: Sebastian Steblecki information already scrapped
# Player: Konrad Nowak information already scrapped
# Player: Przemysław Frankowski information already scrapped
# Player: Jonatan Straus information already scrapped
# Player: Martin Konczkowski information already scrapped
# Player: Adam Deja information already scrapped
# Player: Bartłomiej Kasprzak information already scrapped
# Player: Przemysław Kita information already scrapped
# Player: Patryk Stępiński information already scrapped
# Player: Tomasz Zając information already scrapped
# Player: Piotr Azikiewicz information already scrapped
# Player: Daniel Bujok information already scrapped
# Player: Aleksander Jagiełło information already scrapped
# Player: Piotr Piwowar information already scrapped
# Player: Radosław Murawski information already scrapped
# Player: Piotr Żemło information already scrapped
# Player: Paweł Jaroszyński information already scrapped
# Player: Maciej Urbańczyk information already scrapped
# Player: Paweł Drażba information already scrapped
# Player: Bartosz Narożnik information already scrapped
# Player: Dawid Kamiński information already scrapped
# Player: Damian Kowalczyk information already scrapped
# Player: Adam Dźwigała information already scrapped
# Player: Paweł Dawidowicz information already scrapped
# Player: Karol Linetty information already scrapped
# Player: Michał Helik information already scrapped
# Player: Adam Waszkiewicz information already scrapped
# Player: Marcin Przybylski information already scrapped
# Player: Mateusz Żebrowski information already scrapped
# Player: Wojciech Zyska information already scrapped
# Player: Marcin Cebula information already scrapped
# Player: Jarosław Jach information already scrapped
# Player: Michał Wrześniewski information already scrapped
# Player: Sebastian Bonecki information already scrapped
# Player: Dariusz Formella information already scrapped
# Player: Sebastian Rudol information already scrapped
# Player: Łukasz Żegleń information already scrapped
# Player: Krzysztof Szewczyk information already scrapped
# Player: Kamil Kurowski information already scrapped
# Player: Patryk Mikita information already scrapped
# Player: Damian Ciechanowski information already scrapped
# Player: Daniel Dziwniel information already scrapped
# Player: Emil Gajko information already scrapped
# Player: Paweł Stolarski information already scrapped
# Player: Jarosław Kubicki information already scrapped
# Player: Michał Pawlik information already scrapped
# Player: Konrad Andrzejczak information already scrapped
# Player: Dawid Kownacki information already scrapped
# Player: Michał Przybyła information already scrapped
# Player: Jan Bednarek information already scrapped
# Player: Karol Angielski information already scrapped
# Player: Filip Jagiełło information already scrapped
# Player: Patryk Paczuk information already scrapped
# Player: Bartłomiej Drągowski information already scrapped
# Player: Krzysztof Piątek information already scrapped
# Player: Dawid Kort information already scrapped
# Player: Kamil Dankowski information already scrapped
# Player: Jakub Bartosz information already scrapped
# Player: Bartłomiej Smuczyński information already scrapped
# Player: Dariusz Sosnowski information already scrapped
# Player: Bartosz Kapustka information already scrapped
# Player: Michał Koj information already scrapped
# Player: Korneliusz Sochań information already scrapped
# Player: Michał Walski information already scrapped
# Player: Przemysław Mystkowski information already scrapped
# Player: Kamil Cupriak information already scrapped
# Player: Patrick Dytko information already scrapped
# Player: Filip Kozłowski information already scrapped
# Player: Łukasz Wroński information already scrapped
# Player: Mateusz Szwoch information already scrapped
# Player: Tomasz Mokwa information already scrapped
# Player: Paweł Zięba information already scrapped
# Player: Marcin Flis information already scrapped
# Player: Paweł Czychowski information already scrapped
# Player: Mateusz Szymorek information already scrapped
# Player: Jakub Mrozik information already scrapped
# Player: Mariusz Stępiński information already scrapped
# Player: Piotr Okuniewicz information already scrapped
# Player: Fabian Piasecki information already scrapped
# Player: Norbert Misiak information already scrapped
# Player: Jakub Kotarzewski information already scrapped
# Player: Lukas Klemenz information already scrapped
# Player: Łukasz Zwoliński information already scrapped
# Player: Jakub Wrąbel information already scrapped
# Player: Patryk Lipski information already scrapped
# Player: Damian Garbacik information already scrapped
# Player: Gracjan Horoszkiewicz information already scrapped
# Player: Damian Szymański information already scrapped
# Player: Łukasz Moneta information already scrapped
# Player: Sebastian Murawski information already scrapped
# Player: Robert Obst information already scrapped
# Player: Dominik Sadzawicki information already scrapped
# Player: Adam Buksa information already scrapped
# Player: Michał Bartkowiak information already scrapped
# Player: Przemysław Lech information already scrapped
# Player: Jakub Łukowski information already scrapped
# Player: Robert Bartczak information already scrapped
# Player: Bartłomiej Kalinkowski information already scrapped
# Player: Mateusz Wdowiak information already scrapped
# Player: Wojciech Kalinowski information already scrapped
# Player: Patryk Dziczek information already scrapped
# Player: Dawid Flaszka information already scrapped
# Player: Mateusz Wieteska information already scrapped
# Player: Marcin Listkowski information already scrapped
# Player: Hubert Matynia information already scrapped
# Player: Kamil Wojtkowski information already scrapped
# Player: Adam Ryczkowski information already scrapped
# Player: Jakub Serafin information already scrapped
# Player: Krystian Bielik information already scrapped
# Player: Karol Świderski information already scrapped
# Player: Przemysław Macierzyński information already scrapped
# Player: Martin Kobylański information already scrapped
# Player: Bartosz Jaroch information already scrapped
# Player: Mateusz Janeczko information already scrapped
# Player: Emil Łupiński information already scrapped
# Player: Jakub Mordec information already scrapped
# Player: Bartosz Giełażyn information already scrapped
# Player: Szymon Witek information already scrapped
# Player: Hubert Laskowski information already scrapped
# Player: Dawid Szymonowicz information already scrapped
# Player: Jakub Okuszko information already scrapped
# Player: Igor Sapała information already scrapped
# Player: Kamil Mazek information already scrapped
# Player: Kamil Jonkisz information already scrapped
# Player: Piotr Kurbiel information already scrapped
# Player: Kamil Kuczak information already scrapped
# Player: Sebastian Musiolik information already scrapped
# Player: Krzysztof Drzazga information already scrapped
# Player: Maciej Matusik information already scrapped
# Player: Krystian Kujawa information already scrapped
# Player: Grzegorz Marszalik information already scrapped
# Player: Eryk Sobków information already scrapped
# Player: Konrad Handzlik information already scrapped
# Player: Przemysław Pyrdek information already scrapped
# Player: Jakub Kuzdra information already scrapped
# Player: Łukasz Siedlik information already scrapped
# Player: Rafał Makowski information already scrapped
# Player: Karol Żmijewski information already scrapped
# Player: Kamil Jóźwiak information already scrapped
# Player: Robert Gumny information already scrapped
# Player: Michał Żebrakowski information already scrapped
# Player: Mariusz Idzik information already scrapped
# Player: Jakub Piotrowski information already scrapped
# Player: Paweł Żyra information already scrapped
# Player: Adam Chrzanowski information already scrapped
# Player: Marcin Urynowicz information already scrapped
# Player: Paweł Olszewski information already scrapped
# Player: Hubert Adamczyk information already scrapped
# Player: Przemysław Bargiel information already scrapped
# Player: Arkadiusz Reca information already scrapped
# Player: Damian Podleśny information already scrapped
# Player: Jarosław Niezgoda information already scrapped
# Player: Przemysław Szarek information already scrapped
# Player: Krystian Peda information already scrapped
# Player: Jakub Arak information already scrapped
# Player: Michał Nalepa information already scrapped
# Player: Damian Węglarz information already scrapped
# Player: Daniel Łuczak information already scrapped
# Player: Artur Siemaszko information already scrapped
# Player: Szczepan Kogut information already scrapped
# Player: Patryk Mucha information already scrapped
# Player: Denis Gojko information already scrapped
# Player: Konrad Michalak information already scrapped
# Player: Adrian Henger information already scrapped
# Player: Sebastian Kowalczyk information already scrapped
# Player: Przemysław Porębski information already scrapped
# Player: Piotr Poński information already scrapped
# Player: Radosław Kanach information already scrapped
# Player: Dominik Jończy information already scrapped
# Player: Krystian Popiela information already scrapped
# Player: Tymoteusz Puchacz information already scrapped
# Player: Paweł Tomczyk information already scrapped
# Player: Wojciech Słomka information already scrapped
# Player: Michał Mokrzycki information already scrapped
# Player: Kamil Słoma information already scrapped
# Player: David Niepsuj information already scrapped
# Player: Sebastian Szymański information already scrapped
# Player: Patryk Klimala information already scrapped
# Player: Kamil Pestka information already scrapped
# Player: Adrian Łyszczarz information already scrapped
# Player: Piotr Nowak information already scrapped
# Player: Kacper Laskoś information already scrapped
# Player: Dawid Kieplin information already scrapped
# Player: Łukasz Krakowczyk information already scrapped
# Player: Marcin Mielczarski information already scrapped
# Player: Damian Rasak information already scrapped
# Player: Michał Gałecki information already scrapped
# Player: Bartłomiej Olszewski information already scrapped
# Player: Tomasz Loska information already scrapped
# Player: Paweł Bochniewicz information already scrapped
# Player: Krystian Miś information already scrapped
# Player: Maciej Pałaszewski information already scrapped
# Player: Oskar Zawada information already scrapped
# Player: Adam Wilk information already scrapped
# Player: Dawid Błanik information already scrapped
# Player: Mathieu Scalet information already scrapped
# Player: Krzysztof Kiklaisz information already scrapped
# Player: Jakub Moder information already scrapped
# Player: Dariusz Pawłowski information already scrapped
# Player: Daniel Smuga information already scrapped
# Player: Bartosz Slisz information already scrapped
# Player: Konrad Poprawa information already scrapped
# Player: Hubert Maślanka information already scrapped
# Player: Dawid Pakulski information already scrapped
# Player: Szymon Nowicki information already scrapped
# Player: Karol Fila information already scrapped
# Player: Tymoteusz Klupś information already scrapped
# Player: Dominik Lasik information already scrapped
# Player: Szymon Żurkowski information already scrapped
# Player: Maciej Ambrosiewicz information already scrapped
# Player: Sebastian Bergier information already scrapped
# Player: Sebastian Walukiewicz information already scrapped
# Player: Adrian Benedyczak information already scrapped
# Player: Florian Schikowski information already scrapped
# Player: Daniel Pik information already scrapped
# Player: Jakub Bursztyn information already scrapped
# Player: Sylwester Lusiusz information already scrapped
# Player: Sebastian Strózik information already scrapped
# Player: Wojciech Hajda information already scrapped
# Player: Daniel Liszka information already scrapped
# Player: Jan Łoś information already scrapped
# Player: Mateusz Żukowski information already scrapped
# Player: Adrian Gryszkiewicz information already scrapped
# Player: Wiktor Długosz information already scrapped
# Player: Michał Dziubek information already scrapped
# Player: Michał Rakoczy information already scrapped
# Player: Rafał Kobryń information already scrapped
# Player: Piotr Pierzchała information already scrapped
# Player: Tomasz Nawotka information already scrapped
# Player: Jakub Łabojko information already scrapped
# Player: Damian Oko information already scrapped
# Player: Mateusz Lis information already scrapped
# Player: Mateusz Hołownia information already scrapped
# Player: Adrian Klimczak information already scrapped
# Player: Sebastian Milewski information already scrapped
# Player: Wiktor Biedrzycki information already scrapped
# Player: Mateusz Żyro information already scrapped
# Player: Bartłomiej Żynel information already scrapped
# Player: Tomasz Makowski information already scrapped
# Player: Radosław Majecki information already scrapped
# Player: Patryk Szysz information already scrapped
# Player: Marcin Grabowski information already scrapped
# Player: Mateusz Skrzypczak information already scrapped
# Player: Patryk Makuch information already scrapped
# Player: Michał Ozga information already scrapped
# Player: Hubert Sobol information already scrapped
# Player: Karol Stanek information already scrapped
# Player: Adrian Purzycki information already scrapped
# Player: Paweł Kucharczyk information already scrapped
# Player: Przemysław Wiśniewski information already scrapped
# Player: Daniel Bielica information already scrapped
# Player: Filip Marchwiński information already scrapped
# Player: Maciej Żurawski information already scrapped
# Player: Kacper Michalski information already scrapped
# Player: Oktawian Skrzecz information already scrapped
# Player: Olaf Nowak information already scrapped
# Player: Patryk Plewka information already scrapped
# Player: Michael Olczyk information already scrapped
# Player: Artur Balicki information already scrapped
# Player: Callum Rzonca information already scrapped
# Player: Konrad Kumor information already scrapped
# Player: Paweł Sokół information already scrapped
# Player: Łukasz Poręba information already scrapped
# Player: Maciej Twarowski information already scrapped
# *** Searching for: Piotr Samiec-Talar
# 1 results found
# Adding dob and position
# Matching with 90minut data
# Match found. Generating transfer data.
# File saved succesfully. Path: ../data/transfermarkt_player_data.json
# Player: Oskar Sewerzyński information already scrapped
# Player: Marcel Zapytowski information already scrapped
# Player: Mateusz Sopoćko information already scrapped
# Player: Maciej Śliwa information already scrapped
# Player: Mateusz Młyński information already scrapped
# Player: Roman Janicki information already scrapped
# Player: Tomasz Pietrzak information already scrapped
# Player: Kacper Radkowski information already scrapped
# Player: Kacper Kozłowski information already scrapped
# Player: Mateusz Stępień information already scrapped
# Player: Aleksander Buksa information already scrapped
# Player: Daniel Morys information already scrapped
# Player: Dawid Szot information already scrapped
# Player: Filip Dymerski information already scrapped
# *** Searching for: Daniel Hoyo-Kowalski
# 1 results found
# Adding dob and position
# Matching with 90minut data
# Match found. Generating transfer data.
# File saved succesfully. Path: ../data/transfermarkt_player_data.json
# Player: Daniel Szelągowski information already scrapped
# Player: Marcin Staniszewski information already scrapped
# Player: Michał Trąbka information already scrapped
# Player: Mateusz Spychała information already scrapped
# Player: Maciej Wolski information already scrapped
# Player: Przemysław Płacheta information already scrapped
# Player: Juliusz Letniowski information already scrapped
# Player: Miłosz Szczepański information already scrapped
# Player: Kacper Chodyna information already scrapped
# Player: Miłosz Mleczko information already scrapped
# Player: Grzegorz Szymusik information already scrapped
# Player: Jakub Wawszczyk information already scrapped
# Player: Daniel Mikołajewski information already scrapped
# Player: Damian Michalski information already scrapped
# Player: Wojciech Muzyk information already scrapped
# Player: Daniel Chmielnicki information already scrapped
# Player: Kamil Antonik information already scrapped
# Player: Kacper Kostorz information already scrapped
# Player: Damian Pawłowski information already scrapped
# Player: Michał Skóraś information already scrapped
# Player: David Kopacz information already scrapped
# Player: Przemysław Zdybowicz information already scrapped
# Player: Mateusz Praszelik information already scrapped
# Player: Daniel Ściślak information already scrapped
# Player: Piotr Pyrdoł information already scrapped
# Player: Przemysław Sajdak information already scrapped
# Player: Mateusz Grudziński information already scrapped
# Player: Jakub Kamiński information already scrapped
# Player: Bartłomiej Wdowik information already scrapped
# Player: Jan Sobociński information already scrapped
# Player: Bartosz Bida information already scrapped
# Player: Mikołaj Nawrocki information already scrapped
# Player: Michał Karbownik information already scrapped
# Player: Maciej Rosołek information already scrapped
# Player: Mikołaj Kwietniewski information already scrapped
# Player: Dawid Arndt information already scrapped
# Player: Michał Rostkowski information already scrapped
# Player: Kamil Piątkowski information already scrapped
# Player: Jakub Bator information already scrapped
# Player: Filip Szymczak information already scrapped
# Player: Mateusz Supryn information already scrapped
# Player: Karol Struski information already scrapped
# Player: Aleksander Paluszek information already scrapped
# Player: Marcin Szpakowski information already scrapped
# Player: Mikołaj Wasilewski information already scrapped
# Player: Jakub Górski information already scrapped
# Player: Dawid Lisowski information already scrapped
# Player: Kacper Smoliński information already scrapped
# Player: Marcel Wędrychowski information already scrapped
# Player: Mateusz Sowiński information already scrapped
# Player: Bartosz Białek information already scrapped
# Player: Kacper Krzepisz information already scrapped
# Player: Jakub Osobiński information already scrapped
# Player: Remigiusz Borkała information already scrapped
# Player: Jakub Apolinarski information already scrapped
# Player: Wojciech Błyszko information already scrapped
# Player: Hubert Turski information already scrapped
# Player: Adam Ratajczyk information already scrapped
# Player: Dawid Kocyła information already scrapped
# Player: Kacper Bieszczad information already scrapped
# Player: Jakub Sypek information already scrapped
# Player: Radosław Cielemęcki information already scrapped
# Player: Kamil Kruk information already scrapped
# Player: Dominik Steczyk information already scrapped
# Player: Paweł Żuk information already scrapped
# Player: Ariel Mosór information already scrapped
# Player: Szymon Włodarczyk information already scrapped
# Player: Iwo Kaczmarski information already scrapped
# Player: Aleksander Pawlak information already scrapped
# Player: Aleksander Stawiarz information already scrapped
# Player: Jakub Wilczyński information already scrapped
# Player: Radosław Seweryś information already scrapped
# Player: Krzysztof Toporkiewicz information already scrapped
# Player: Kacper Urbański information already scrapped
# Player: Jakub Kałuziński information already scrapped
# Player: Ben Lederman information already scrapped
# Player: Dawid Markiewicz information already scrapped
# Player: Xavier Dziekoński information already scrapped
# Player: Mateusz Kaczmarek information already scrapped
# Player: Jakub Witek information already scrapped
# Player: Tomasz Bała information already scrapped
# Player: Patryk Soboczyński information already scrapped
# Player: Serafin Szota information already scrapped
# Player: Konrad Gutowski information already scrapped
# Player: Rafał Strączek information already scrapped
# Player: Bartłomiej Burman information already scrapped
# Player: Mateusz Winciersz information already scrapped
# Player: Bartłomiej Gradecki information already scrapped
# Player: Karol Niemczycki information already scrapped
# Player: Łukasz Zjawiński information already scrapped
# Player: Jan Biegański information already scrapped
# Player: Krzysztof Kubica information already scrapped
# Player: Kacper Sadłocha information already scrapped
# Player: Cezary Miszta information already scrapped
# Player: Patryk Zaucha information already scrapped
# Player: Szymon Lewkot information already scrapped
# Player: Maksymilian Sitek information already scrapped
# Player: Dominik Frelek information already scrapped
# Player: Maciej Bortniczuk information already scrapped
# Player: Kacper Rogoziński information already scrapped
# Player: Arkadiusz Pyrka information already scrapped
# Player: Kacper Skibicki information already scrapped
# Player: Szymon Stasik information already scrapped
# Player: Aleks Ławniczak information already scrapped
# Player: Jakub Bednarczyk information already scrapped
# Player: Łukasz Seweryn information already scrapped
# Player: Jakub Bieroński information already scrapped
# Player: Bartłomiej Mruk information already scrapped
# Player: Krystian Wachowiak information already scrapped
# Player: Mateusz Wyjadłowski information already scrapped
# Player: Kajetan Szmyt information already scrapped
# Player: Bartosz Zynek information already scrapped
# Player: Maik Nawrocki information already scrapped
# Player: Marcel Zylla information already scrapped
# Player: Łukasz Łakomy information already scrapped
# Player: Antoni Kozubal information already scrapped
# Player: Krystian Palacz information already scrapped
# Player: Mariusz Fornalczyk information already scrapped
# Player: Michał Rakowiecki information already scrapped
# Player: Filip Laskowski information already scrapped
# Player: Norbert Wojtuszek information already scrapped
# Player: Konrad Gruszkowski information already scrapped
# Player: Javier Ajenjo Hyjek information already scrapped
# Player: Szymon Mroczko information already scrapped
# Player: Przemysław Kapek information already scrapped
# Player: Jakub Myszor information already scrapped
# Player: Mateusz Lewandowski information already scrapped
# Player: Norbert Pacławski information already scrapped
# Player: Jakub Gut information already scrapped
# Player: Jakub Orpik information already scrapped
# Player: Szymon Pankiewicz information already scrapped
# Player: Jakub Kisiel information already scrapped
# Player: Miłosz Matysik information already scrapped
# Player: Przemysław Maj information already scrapped
# Player: Łukasz Bejger information already scrapped
# Player: Filip Koperski information already scrapped
# Player: Piotr Starzyński information already scrapped
# Player: Milan Posmyk information already scrapped
# Player: Bartłomiej Kręcichwost information already scrapped
# Player: Kacper Tabiś information already scrapped
# Player: Bartosz Mrozek information already scrapped
# Player: Kacper Śpiewak information already scrapped
# Player: Michał Król information already scrapped
# Player: Szymon Czyż information already scrapped
# Player: Michael Ameyaw information already scrapped
# Player: Filip Majchrowicz information already scrapped
# Player: Mateusz Kochalski information already scrapped
# Player: Mikołaj Biegański information already scrapped
# Player: Konrad Matuszewski information already scrapped
# Player: Oskar Krzyżak information already scrapped
# Player: Jakub Nowakowski information already scrapped
# Player: Ernest Terpiłowski information already scrapped
# Player: Robert Ożóg information already scrapped
# Player: Jędrzej Grobelny information already scrapped
# Player: Bartłomiej Kukułowicz information already scrapped
# Player: Eryk Matus information already scrapped
# Player: Jakub Iskra information already scrapped
# Player: Kryspin Szcześniak information already scrapped
# Player: Patryk Czerech information already scrapped
# Player: Michał Orzechowski information already scrapped
# Player: Dennis Jastrzembski information already scrapped
# Player: Rafał Adamski information already scrapped
# Player: Kamil Ogorzały information already scrapped
# Player: Daniel Dudziński information already scrapped
# Player: Kacper Lepczyński information already scrapped
# Player: Kacper Tobiasz information already scrapped
# Player: Bartłomiej Ciepiela information already scrapped
# Player: Mateusz Łęgowski information already scrapped
# Player: Adrian Bukowski information already scrapped
# Player: Patryk Kusztal information already scrapped
# Player: Jakub Sangowski information already scrapped
# Player: Łukasz Szramowski information already scrapped
# Player: Jakub Pek information already scrapped
# Player: Michał Goliński information already scrapped
# Player: Adrian Szczutowski information already scrapped
# Player: Wiktor Kłos information already scrapped
# Player: Kacper Trelowski information already scrapped
# Player: Marcin Szeibe information already scrapped
# Player: Kacper Sezonienko information already scrapped
# Player: Fryderyk Gerbowski information already scrapped
# Player: Filip Gryglak information already scrapped
# Player: Krystian Bracik information already scrapped
# Player: Adrian Dziedzic information already scrapped
# Player: Jakub Szymański information already scrapped
# Player: Bartłomiej Kłudka information already scrapped
# Player: Jakub Antczak information already scrapped
# Player: Tomasz Neugebauer information already scrapped
# Player: Karol Knap information already scrapped
# Player: Oliwier Wojciechowski information already scrapped
# Player: Radosław Zyśk information already scrapped
# Player: Tomasz Pieńko information already scrapped
# Player: Oliwier Sławiński information already scrapped
# Player: Jakub Lutostański information already scrapped
# Player: Michael Wyparło information already scrapped
# Player: Dawid Tkacz information already scrapped
# Player: Dawid Krzyżański information already scrapped
# Player: Igor Strzałek information already scrapped
# Player: Igor Drapiński information already scrapped
# Player: Mikołaj Rakowski information already scrapped
# Player: Marcel Błachewicz information already scrapped
# Player: Dariusz Stalmach information already scrapped
# Player: Kacper Masiak information already scrapped
# Player: Tomasz Walczak information already scrapped
# Player: David Poreba information already scrapped
# Player: Karol Borys information already scrapped
# Player: Jakub Snopczyński information already scrapped
# Player: Mateusz Ziółkowski information already scrapped
# Player: Michał Szałachowski information already scrapped
# Player: Olaf Kobacki information already scrapped
# Player: Wiktor Pleśnierowicz information already scrapped
# Player: Gabriel Kobylak information already scrapped
# Player: Ignacy Dawid information already scrapped
# Player: Jakub Konstantyn information already scrapped
# Player: Filip Wilak information already scrapped
# Player: Dominik Piła information already scrapped
# Player: Patryk Szwedzik information already scrapped
# Player: Bartosz Klebaniuk information already scrapped
# Player: Albert Posiadała information already scrapped
# Player: Dawid Więckowski information already scrapped
# Player: Szczepan Mucha information already scrapped
# Player: Michał Stachera information already scrapped
# Player: Dawid Bałdyga information already scrapped
# Player: Nikodem Zielonka information already scrapped
# Player: Maksymilian Pingot information already scrapped
# Player: Sławomir Abramowicz information already scrapped
# Player: Jakub Ojrzyński information already scrapped
# Player: Paweł Chrupałła information already scrapped
# Player: Wiktor Kamiński information already scrapped
# Player: Łukasz Gerstenstein information already scrapped
# Player: Mateusz Stawny information already scrapped
# Player: Hubert Szulc information already scrapped
# Player: Filip Kocaba information already scrapped
# Player: Bartłomiej Kolec information already scrapped
# Player: Jakub Jędrasik information already scrapped
# Player: Janusz Nojszewski information already scrapped
# Player: Gabriel Kirejczyk information already scrapped
# Player: Mateusz Kempski information already scrapped
# Player: Filip Zawadzki information already scrapped
# Player: Mateusz Kowalski information already scrapped
# Player: Jakub Lewicki information already scrapped
# Player: Krzysztof Kolanko information already scrapped
# Player: Tobiasz Kubik information already scrapped
# Player: Michael Kostka information already scrapped
# Player: Adam Dębiński information already scrapped
# Player: Krystian Okoniewski information already scrapped
# Player: Krystian Kardyś information already scrapped
# Player: Szymon Sarbinowski information already scrapped
# Player: Jakub Paszkowski information already scrapped
# Player: Dawid Drachal information already scrapped
# Player: Kacper Śmiglewski information already scrapped
# Player: Adrian Przyborek information already scrapped
# Player: Michał Gurgul information already scrapped
# Player: Jędrzej Hanuszczak information already scrapped
# Player: Filip Rózga information already scrapped
# Player: Krzysztof Bąkowski information already scrapped
# Player: Adam Kramarz information already scrapped
# Player: Mateusz Chmarek information already scrapped
# Player: Kamil Lukoszek information already scrapped
# Player: Kacper Skwierczyński information already scrapped
# Player: Filip Borowski information already scrapped
# Player: Kewin Komar information already scrapped
# Player: Dominik Marczuk information already scrapped
# Player: Oliwier Zych information already scrapped
# Player: Krzysztof Wróblewski information already scrapped
# Player: Aleksander Bobek information already scrapped
# Player: Jan Krzywański information already scrapped
# *** Searching for: Kelechukwu Ibe-Torti
# 1 results found
# Adding dob and position
# Matching with 90minut data
# Match found. Generating transfer data.
# File saved succesfully. Path: ../data/transfermarkt_player_data.json
# Player: Jędrzej Zając information already scrapped
# Player: Marcel Bykowski information already scrapped
# Player: Miłosz Strzeboński information already scrapped
# Player: Szymon Weirauch information already scrapped
# Player: Tomasz Wójtowicz information already scrapped
# Player: Jakub Jezierski information already scrapped
# Player: Jordan Majchrzak information already scrapped
# Player: Antoni Klimek information already scrapped
# Player: Maksymilian Dziuba information already scrapped
# Player: Patryk Malamis information already scrapped
# Player: Olaf Korczakowski information already scrapped
# Player: Grzegorz Glapka information already scrapped
# Player: Norbert Barczak information already scrapped
# Player: Filip Rejczyk information already scrapped
# Player: Damian Wojdakowski information already scrapped
# Player: Kacper Przybyłko information already scrapped
# Player: Wojciech Urbański information already scrapped
# Player: Jakub Wajman information already scrapped
# Player: Jan Łabędzki information already scrapped
# Player: Bartłomiej Barański information already scrapped
# Player: Oskar Leśniak information already scrapped
# Player: Jan Ziółkowski information already scrapped
# Player: Piotr Liszewski information already scrapped
# Player: Filip Gil information already scrapped
# Player: Jakub Stec information already scrapped
# Player: Krzysztof Kurowski information already scrapped
# Player: Dominik Szala information already scrapped
# Player: Antoni Młynarczyk information already scrapped
# Player: Mike Huras information already scrapped
# Player: Alan Rybak information already scrapped
# Player: Daniel Bąk information already scrapped
# Player: Patryk Rychlik information already scrapped
# Player: Kamil Cybulski information already scrapped
# Player: Filip Przybułek information already scrapped
# Player: Piotr Urbański information already scrapped
# Player: Aleksander Iwańczyk information already scrapped
# Player: Tommaso Guercio information already scrapped
# Player: Igor Pieprzyca information already scrapped
# Player: Paweł Kwiatkowski information already scrapped
# Player: Patryk Paryzek information already scrapped
# Player: Fabian Bzdyl information already scrapped
# Player: Guilherme Zimovski information already scrapped
# Player: Alex Cetnar information already scrapped
# Player: Filip Tonder information already scrapped
# Player: Bartosz Baranowicz information already scrapped
# Player: Wiktor Koptas information already scrapped
# Player: Oskar Wójcik information already scrapped
# Player: Hubert Zwoźny information already scrapped
# Player: Kacper Łukasiak information already scrapped
# Player: Maciej Kikolski information already scrapped
# Player: Mateusz Kowalczyk information already scrapped
# Player: Bartłomiej Smolarczyk information already scrapped
# Player: Dawid Zięba information already scrapped
# Player: Jakub Mądrzyk information already scrapped
# Player: Szymon Rygiel information already scrapped
# Player: Cezary Polak information already scrapped
# Player: Jakub Kolan information already scrapped
# Player: Mateusz Bąk information already scrapped
# Player: Marcel Krajewski information already scrapped
# Player: Patryk Romanowski information already scrapped
# Player: Michał Głogowski information already scrapped
# Player: Mateusz Dziewiatowski information already scrapped
# Player: Igor Orlikowski information already scrapped
# Player: Marcel Reguła information already scrapped
# Player: Alan Bród information already scrapped
# Player: Bartosz Biedrzycki information already scrapped
# Player: Rafał Mamla information already scrapped
# Player: Filip Luberecki information already scrapped
# Player: Aleksander Wołczek information already scrapped
# Player: Wojciech Mońka information already scrapped
# Player: Daniel Mikołajewski information already scrapped
# Player: Dawid Mazurek information already scrapped
# Player: Dominik Sarapata information already scrapped
# Player: Oliwier Olewiński information already scrapped
# Player: Mateusz Szczepaniak information already scrapped
# Player: Oskar Lachowicz information already scrapped
# Player: Bartosz Mazurek information already scrapped
# Player: Kamil Nowogoński information already scrapped
# Player: Aleksander Tobolik information already scrapped
# Player: Oskar Pietuszewski information already scrapped
# Player: Kornel Lisman information already scrapped
# Player: Adam Kardaś information already scrapped
# Player: Michał Perchel information already scrapped
# Player: Nikodem Stachowicz information already scrapped
# Player: Antoni Klukowski information already scrapped
# Player: Maximillian Oyedele information already scrapped
# Player: Sammy Dudek information already scrapped
# Player: Adam Chojecki information already scrapped
# Player: Pascal Mozie information already scrapped
# Player: Dawid Kogut information already scrapped
# Player: Konrad Ciszek information already scrapped
# Player: Natan Niedźwiedź information already scrapped
# Player: Levis Pitan information already scrapped
# Player: Bright Ede information already scrapped
# Player: Adam Basse information already scrapped
# Player: Daniel Gryzio information already scrapped
# Player: Aleksander Wyganowski information already scrapped
# Player: Leon Madej information already scrapped
# Player: Mateusz Kopczyński information already scrapped
# Player: Dawid Polak information already scrapped

# %% [markdown]
# #### adding 3 players manually - date of birth match did not work

# %%
transfermarkt_data_json = dm._load_json('../data/transfermarkt_player_data.json')

# %%
transfermarkt_data_no_match_json = dm._load_json('../data/transfermarkt_player_data_no_match.json')

# %%
data_90minut = dm._load_pickle('../data/player_personal_data.pickle')

# %%
data_90minut[23170]
# Out:
# {'country': 'Polska',
#  'date_of_birth': '22 marca 1995',
#  'year_of_birth': '1995',
#  'Imie i nazwisko': 'Hubert Laskowski'}

# %%
data_90minut[24217]
# Out:
# {'country': 'Polska',
#  'date_of_birth': '3 marca 1995',
#  'year_of_birth': '1995',
#  'Imie i nazwisko': 'Jakub Okuszko'}

# %%
for player in transfermarkt_data_no_match_json:
    transfermarkt_data_json.append(player)

# %%
len(transfermarkt_data_json)
# Out:
# 698

# %%
dm._save_json(transfermarkt_data_json, '../data/transfermarkt_player_data.json')
# Out:
# File saved succesfully. Path: ../data/transfermarkt_player_data.json

# %% [markdown]
# #### position extraction validation

# %%
pos_check = {}

# %%
for player in transfermarkt_data_json:
    if player.position in pos_check.keys():
        pos_check[player.position] += 1
    else:
        pos_check[player.position] = 1

# %%
pos_check.keys()
# Out:
# dict_keys(['Rechter Verteidiger', 'Defensives Mittelfeld', 'Innenverteidiger', 'Offensives Mittelfeld', 'Mittelstürmer', 'Torwart', 'Zentrales Mittelfeld', 'Linksaußen', 'Linker Verteidiger', 'Rechtsaußen', 'Linkes Mittelfeld', 'Sturm', 'Rechtes Mittelfeld', 'Mittelfeld', 'Abwehr', 'zuletzt bei Pogon Staszow'])

# %%
for player in transfermarkt_data_json:
    if player.position == 'zuletzt bei Pogon Staszow':
        print(player.name)
# Out:
# Hubert Laskowski

# %%
for player in transfermarkt_data_json:
    if player.name == 'Hubert Laskowski':
        player.position = 'Rechtsaußen'

# %%
for player in transfermarkt_data_json:
    if player.name == 'Hubert Laskowski':
        print(player)
# Out:
# TransfermarktPlayer(player_id=381720, name='Hubert Laskowski', profile_url='https://www.transfermarkt.de/hubert-laskowski/profil/spieler/381720', date_of_birth=None, position='Rechtsaußen', transfers=[Transfer(season='18/19', date='01.01.2019', left='Pogon Staszow', joined='Karriereende', mv='-', fee='-'), Transfer(season='18/19', date='01.07.2018', left='Eintr. Elster', joined='Pogon Staszow', mv='-', fee='ablösefrei'), Transfer(season='17/18', date='01.01.2018', left='Partyzant', joined='Eintr. Elster', mv='-', fee='ablösefrei'), Transfer(season='17/18', date='01.08.2017', left='Korona Kielce', joined='Partyzant', mv='50 Tsd. €', fee='ablösefrei'), Transfer(season='16/17', date='30.06.2017', left='Spartakus Daleszyce', joined='Korona Kielce', mv='50 Tsd. €', fee='Leih-Ende'), Transfer(season='16/17', date='10.02.2017', left='Korona Kielce', joined='Spartakus Daleszyce', mv='50 Tsd. €', fee='Leihe'), Transfer(season='16/17', date='08.12.2016', left='Kotwica', joined='Korona Kielce', mv='-', fee='Leih-Ende'), Transfer(season='16/17', date='28.07.2016', left='Korona Kielce', joined='Kotwica', mv='50 Tsd. €', fee='Leihe'), Transfer(season='15/16', date='16.07.2015', left='Korona Kielce II', joined='Korona Kielce', mv='-', fee='-'), Transfer(season='12/13', date='01.07.2012', left='Korona Jugend', joined='Korona Kielce II', mv='-', fee='-')], id_90minut=23170)

# %%
dm._save_json(transfermarkt_data_json, '../data/transfermarkt_player_data.json')
# Out:
# File saved succesfully. Path: ../data/transfermarkt_player_data.json

# %% [markdown]
# #### club, position, price normalization

# %%
import pandas as pd

# %%
t_to_pq = dm._load_json('../data/transfermarkt_player_data.json')

# %%
t_dict =  {'ID 90minut' : [],
           'ID transfermarkt' : [], 
           'Imie i Nazwisko' : [], 
           'Pozycja' : [], 
           'Transfer: sezon' : [], 
           'Transfer: data' : [],
           'Transfer: z klubu' : [], 
           'Transfer: do klubu' : [], 
           'Transfer: wartość rynkowa' : [], 
           'Transfer: cena' : []}

# %%
position_dict_mapping = {
'Abwehr' : 'Obrona',
'Defensives Mittelfeld' : 'Defensywny pomocnik',
'Innenverteidiger' : 'Środkowy obrońca',
'Linker Verteidiger' : 'Lewy obrońca',
'Linkes Mittelfeld' : 'Lewy pomocnik',
'Linksaußen' : 'Lewy skrzydłowy',
'Mittelfeld' : 'Pomocnik',
'Mittelstürmer' : 'Środkowy napastnik',
'Offensives Mittelfeld' : 'Ofensywny pomocnik',
'Rechter Verteidiger' : 'Prawy obrońca',
'Rechtes Mittelfeld' : 'Prawy pomocnik',
'Rechtsaußen' : 'Prawy skrzydłowy',
'Sturm' : 'Napastnik',
'Torwart' : 'Bramkarz',
'Zentrales Mittelfeld' : 'Środkowy pomocnik'
}

# %%
club_mapping = {
'Arka Gdynia' : 'Arka Gdynia',
'Nieciecza' : 'Bruk-Bet Termalica Nieciecza',
'Cracovia' : 'Cracovia',
'GKS Belchatow' : 'GKS Bełchatów',
'GKS Katowice' : 'GKS Katowice',
'Gornik Leczna' : 'Górnik Łęczna',
'Górnik Zabrze' : 'Górnik Zabrze',
'Jagiellonia' : 'Jagiellonia Białystok',
'Korona Kielce' : 'Korona Kielce',
'Lech Posen' : 'Lech Poznań',
'Lechia Gdansk' : 'Lechia Gdańsk',
'Legia Warschau' : 'Legia Warszawa',
'LKS Lodz' : 'ŁKS Łódź',
'Miedz Legnica' : 'Miedź Legnica',
'Motor Lublin' : 'Motor Lublin',
'Piast Gliwice' : 'Piast Gliwice',
'Podbeskidzie' : 'Podbeskidzie Bielsko-Biała',
'Pogon Stettin' : 'Pogoń Szczecin',
'P. Niepolomice' : 'Puszcza Niepołomice',
'Radomiak' : 'Radomiak Radom',
'Raków' : 'Raków Częstochowa',
'Ruch Chorzow' : 'Ruch Chorzów',
'Sandecja' : 'Sandecja Nowy Sącz',
'Stal Mielec' : 'Stal Mielec',
'Slask Wroclaw' : 'Śląsk Wrocław',
'Nieciecza' : 'Termalica Bruk-Bet Nieciecza',
'Warta Posen' : 'Warta Poznań',
'Widzew Lodz' : 'Widzew Łódź',
'Wisla Krakau' : 'Wisła Kraków',
'Wisla Plock' : 'Wisła Płock',
'Zaglebie Lubin' : 'Zagłębie Lubin',
'Z. Sosnowiec' : 'Zagłębie Sosnowiec',
'Zawisza' : 'Zawisza Bydgoszc'
}

# %%
def price_norm(txt):
    txt = txt.replace('</i>', '')
    txt = txt.replace('€', '').strip()
    if 'Leihgebühr:<br /><i class="normaler-text">' in txt:
        txt = 'wypożyczenie'
    if 'Mio.' in txt:
        price, nominator = txt.split()
        price_float = float(price.replace(',', '.'))
        txt = str(int(price_float*1000000))
    if 'Tsd.' in txt:
        price, nominator = txt.split()
        price_float = float(price.replace(',', '.'))
        txt = str(int(price_float*1000))
    if txt == 'ablösefrei':
        txt = 'za darmo'
    if txt == 'Leih-Ende':
        txt = 'koniec wypożyczenia'
    if txt == 'Leihe':
        txt = 'wypożyczenie'
    return txt

# %%
def season_parse(txt):
    start, end = txt.split('/')
    new_start = '20'+start
    new_end = '20'+end
    new_txt = new_start+r'/'+new_end
    return new_txt

# %%
for player in t_to_pq:
    for transfer in player.transfers:
        t_dict['ID 90minut'].append(player.id_90minut)
        t_dict['ID transfermarkt'].append(player.player_id)
        t_dict['Imie i Nazwisko'].append(player.name)
        t_dict['Pozycja'].append(position_dict_mapping[player.position])
        t_dict['Transfer: sezon'].append(season_parse(transfer.season))
        t_dict['Transfer: data'].append(transfer.date)
        if transfer.left in club_mapping.keys():
            t_dict['Transfer: z klubu'].append(club_mapping[transfer.left])
        else:
            t_dict['Transfer: z klubu'].append(transfer.left)
        if transfer.joined in club_mapping.keys():
            t_dict['Transfer: do klubu'].append(club_mapping[transfer.joined])
        else:
            t_dict['Transfer: do klubu'].append(transfer.joined)
        t_dict['Transfer: wartość rynkowa'].append(price_norm(transfer.mv))
        t_dict['Transfer: cena'].append(price_norm(transfer.fee))

# %%
for k,v in t_dict.items():
    print(f'{k}: {len(v)}')
# Out:
# ID 90minut: 5955
# ID transfermarkt: 5955
# Imie i Nazwisko: 5955
# Pozycja: 5955
# Transfer: sezon: 5955
# Transfer: data: 5955
# Transfer: z klubu: 5955
# Transfer: do klubu: 5955
# Transfer: wartość rynkowa: 5955
# Transfer: cena: 5955

# %%
t_pd = pd.DataFrame(t_dict)

# %%
t_pd.head()
# Out:
#    ID 90minut  ID transfermarkt  Imie i Nazwisko        Pozycja  \
# 0       12027            158798  Piotr Mroziński  Prawy obrońca
# 1       12027            158798  Piotr Mroziński  Prawy obrońca
# 2       12027            158798  Piotr Mroziński  Prawy obrońca
# 3       12027            158798  Piotr Mroziński  Prawy obrońca
# 4       12027            158798  Piotr Mroziński  Prawy obrońca
#
#   Transfer: sezon Transfer: data   Transfer: z klubu   Transfer: do klubu  \
# 0       2021/2022     15.07.2021        Stalowa Wola  Puszcza Niepołomice
# 1       2018/2019     17.07.2018       Pogon Siedlce         Stalowa Wola
# 2       2016/2017     04.01.2017         Wisła Płock        Pogon Siedlce
# 3       2015/2016     06.07.2015         Widzew Łódź          Wisła Płock
# 4       2012/2013     30.06.2013  Sandecja Nowy Sącz          Widzew Łódź
#
#   Transfer: wartość rynkowa       Transfer: cena
# 0                         -             za darmo
# 1                     75000             za darmo
# 2                    150000             za darmo
# 3                    200000             za darmo
# 4                    200000  koniec wypożyczenia

# %%
t_pd.to_parquet('../data/transfermarkt_player_data_final_v2.parquet', engine = 'fastparquet')
